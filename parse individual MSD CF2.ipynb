# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import glob

# %%
files = glob.glob("/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/*.xlsx")

# %%
files
# Out:
# ['/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region2 - 1 movies auto tracked - MSD.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region2 - 1 movies auto tracked - Trajectories.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region3 - 1 movies auto tracked - MSD.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region3 - 1 movies auto tracked - Trajectories.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region5 - 1 movies auto tracked - MSD.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/CFS2 MPT/20140521 CFS-20140520-2 s1 PLGA-PEG region5 - 1 movies auto tracked - Trajectories.xlsx']

# %%
imsds = pd.concat([pd.read_excel(f, header=None).iloc[:, 3:] for f in files], 1)

# %%
imsds.to_csv('/Users/dallan/Documents/Repos/pa/cfs2-imsds.csv', header=False, index=False)

# %%
fig, ax = plt.subplots()
ax.plot(imsds)
ax.set(xscale='log', yscale='log')
# Out:
# <img src="data:image/png;base64,...">
# [None, None]

# %%
imsds.shape
# Out:
# (199, 1852)
