# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import glob

# %%
files = glob.glob("/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/Fibrin*")

# %%
files
# Out:
# ['/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 1.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 2.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 3.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 4.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 6.xlsx',
#  '/Users/dallan/Dropbox/MPT data for PANDA paper/Fibrin - 20140508 - tracked by Josh with aptitude/FibrinMSD 7.xlsx']

# %%
imsds = pd.concat([pd.read_excel(f, header=None).iloc[:, 3:] for f in files], 1)

# %%
imsds.to_csv('/Users/dallan/Documents/Repos/pa/fibrin-imsds.csv', header=False, index=False)

# %%
fig, ax = plt.subplots()
ax.plot(imsds)
ax.set(xscale='log', yscale='log')
# Out:
# <img src="data:image/png;base64,...">
# [None, None]

# %%
imsds.shape
# Out:
# (199, 1852)

# %%
# !gist "parse individual MSD.ipynb"
# Out:
# https://gist.github.com/3651b0dd82cc7c7d21da
